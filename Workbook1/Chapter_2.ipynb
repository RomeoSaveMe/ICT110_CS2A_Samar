# %% [markdown]
# EXERCISE 1

# %%
Enter your name: Chuck
Hello Chuck

#name=(input("Enter your name:"))
 print("Hello",name)
# Out:
# Enter your name:mioki'
# Hello mioki'

# %% [markdown]
# EXERCISE 2

# %%
Enter Hours: 35
Enter Rate: 2.75
Pay: 96.25


#rate= (input("Enter Rate:"))
hours= (input("Enter hours:"))
pay= int(rate)*int(hours)
print(pay)
# Out:
# Enter Rate:5
# Enter hours:5
# 25

# %% [markdown]
# EXERCISE 3

# %%
width//2
width/2.0
height/3
1 + 2 * 5

#width = 17
r=width //2
print(r)
print('int')

# %%
width=17
r=width/2.0
print(r)
print('float')

# %%
height=12.0
r=height/3
print(r)
print('float')

# %%
a=1+2*5
print(a)
print('int')

# %% [markdown]
# EXERCISE 4

# %%
Enter a number: 3
The square of 3 is 9
 #number=int(input("Enter a number:"))
 root=number**2
 print("the square of",number,"is",root)

# %% [markdown]
# CHALLENGE

# %%
cel=float (input('Enter temprature in celsius:'))
far= (cel* 9/5)+32
print('Temprature in fahrenheit',far)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-a12b78b7295a> in <cell line: 1>()
# ----> 1 cel=float (input('Enter temprature in celsius:'))
#       2 far= (cel* 9/5)+32
#       3 print('Temprature in fahrenheit',far)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
