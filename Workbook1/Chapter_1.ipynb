# %% [markdown]
# EXERCISE 1

# %%
Print('Hello world!') #The "P" in print is in capital

# %%
print'Hello world!') #There is no parenthesis before the hello world

# %%
print('Hello world!)  #there is no quotation mark after the exclamation mark\

# %%
print('Hello world!'') #double quotation

# %% [markdown]
# EXERCISE 2

# %%
x = 43
x = x + 1
print(x) #The result is 44 because 43 + 1

# %% [markdown]
# EXERCISE 3

# %%
x = 43
x = X + 1
print(x) #The x in equation is capital
