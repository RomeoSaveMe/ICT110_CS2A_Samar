# %% [markdown]
# EXERCISE 1

# %%
x=int (input('Enter number:'))
if x > 50 :
  print ('Above 50')
  elif x > 20:
    print ('Above 20')
    elif x >10:
      print ('Above 10')
      elif x > 0:
        print ('Above 0')
        else:
          print ('Something else')

# %% [markdown]
# EXERCISE 2

# %%
hours=float(input('Enter hours worked:'))
rate= float(input('Enter rate: '))
if hours>40:
  pay=40*rate=((hours-40)*(1.5*rate))
  print ('Pay:',pay)
  else:
    pay=hours*rate
    print('PAy',pay)

# %% [markdown]
# CHALLENGE

# %%
score=int(input('Enter score:'))
if 97<=100:
  print('grades:1.0')
  elif 93<=score<=97:
    print('grades:1.25')
    elif 89<=scoree<=93:
      print('grades:1.5')
      elif 85<=score<=89:
        print('grades:1.75')
        elif 81<=score<=85:
          print('grades:2.0')
# Out:
#   File "<ipython-input-1-4c8798895b0a>", line 4
#     elif 93<=score<=97:
#     ^
# SyntaxError: invalid syntax
